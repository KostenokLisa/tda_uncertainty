# %% [markdown]
# Initial accuracy score on the validation set 0.85

# %%
plt.xlabel("rejection rate")
plt.ylabel("accuracy_score")
plt.title("Accuracy rejection curve (train)")
plt.grid()   
plt.plot(r_rate, total_accuracy) 
plt.show()

# %%
plt.xlabel("rejection rate")
plt.ylabel("accuracy_score")
plt.title("Accuracy rejection curve (eval)")
plt.grid()   
plt.plot(r_rate, total_accuracy) 
plt.show()

# %% [markdown]
# Ripser features & accuracy train set

# %%
ripser_feature_names=[
    'h0_s', # 1 - sum of lengths
    'h0_e', # 2 - entropy 
    'h0_t_d', # 3 - time of death for the longest barcode
    'h0_n_d_m_t0.75', # 4 - number of barcodes with death time > threshold
    'h0_n_d_m_t0.5', # 5 - number of barcodes with death time > threshold
    'h0_n_d_l_t0.25', # 6 - number of barcodes with death time < threshold
    'h1_t_b', # 7 - time of birth for the longest barcode
    'h1_n_b_m_t0.25', # 8 - number of barcodes with birth time > threshold
    'h1_n_b_l_t0.95', # 9 - number of barcodes with birth time < threshold
    'h1_n_b_l_t0.70', # 10 - number of barcodes with birth time < threshold
    'h1_s', # 11 - sum of lengths
    'h1_e', # 12 - entropy
    'h1_v', # 13 - variance of lenghts
    'h1_nb' # 14 - number of barcodes in dim
]

# %%
corr = train_mean_res.corr()
corr.style.background_gradient(cmap='Spectral')
# Out:
# <style type="text/css">
# #T_914ca_row0_col0, #T_914ca_row0_col1, #T_914ca_row0_col3, #T_914ca_row0_col4, #T_914ca_row0_col6, #T_914ca_row0_col7, #T_914ca_row0_col8, #T_914ca_row0_col10, #T_914ca_row0_col11, #T_914ca_row0_col12, #T_914ca_row0_col13, #T_914ca_row1_col0, #T_914ca_row1_col1, #T_914ca_row1_col3, #T_914ca_row1_col4, #T_914ca_row1_col6, #T_914ca_row1_col7, #T_914ca_row1_col8, #T_914ca_row1_col11, #T_914ca_row1_col12, #T_914ca_row1_col13, #T_914ca_row2_col2, #T_914ca_row3_col0, #T_914ca_row3_col1, #T_914ca_row3_col3, #T_914ca_row3_col4, #T_914ca_row3_col6, #T_914ca_row3_col8, #T_914ca_row3_col10, #T_914ca_row3_col11, #T_914ca_row4_col0, #T_914ca_row4_col1, #T_914ca_row4_col3, #T_914ca_row4_col4, #T_914ca_row4_col6, #T_914ca_row4_col8, #T_914ca_row4_col10, #T_914ca_row4_col11, #T_914ca_row5_col5, #T_914ca_row6_col0, #T_914ca_row6_col1, #T_914ca_row6_col3, #T_914ca_row6_col4, #T_914ca_row6_col6, #T_914ca_row6_col11, #T_914ca_row6_col12, #T_914ca_row7_col0, #T_914ca_row7_col1, #T_914ca_row7_col7, #T_914ca_row7_col8, #T_914ca_row7_col11, #T_914ca_row7_col12, #T_914ca_row7_col13, #T_914ca_row8_col0, #T_914ca_row8_col1, #T_914ca_row8_col3, #T_914ca_row8_col4, #T_914ca_row8_col7, #T_914ca_row8_col8, #T_914ca_row8_col11, #T_914ca_row8_col12, #T_914ca_row8_col13, #T_914ca_row9_col9, #T_914ca_row10_col0, #T_914ca_row10_col3, #T_914ca_row10_col4, #T_914ca_row10_col10, #T_914ca_row10_col11, #T_914ca_row11_col0, #T_914ca_row11_col1, #T_914ca_row11_col3, #T_914ca_row11_col4, #T_914ca_row11_col6, #T_914ca_row11_col7, #T_914ca_row11_col8, #T_914ca_row11_col10, #T_914ca_row11_col11, #T_914ca_row11_col12, #T_914ca_row11_col13, #T_914ca_row12_col0, #T_914ca_row12_col1, #T_914ca_row12_col6, #T_914ca_row12_col7, #T_914ca_row12_col8, #T_914ca_row12_col11, #T_914ca_row12_col12, #T_914ca_row12_col13, #T_914ca_row13_col0, #T_914ca_row13_col1, #T_914ca_row13_col7, #T_914ca_row13_col8, #T_914ca_row13_col11, #T_914ca_row13_col12, #T_914ca_row13_col13, #T_914ca_row14_col14 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_914ca_row0_col2, #T_914ca_row2_col0, #T_914ca_row2_col6, #T_914ca_row2_col10, #T_914ca_row6_col2, #T_914ca_row9_col10, #T_914ca_row10_col2, #T_914ca_row10_col9 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_914ca_row0_col5, #T_914ca_row5_col3, #T_914ca_row6_col5 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_914ca_row0_col9, #T_914ca_row9_col6, #T_914ca_row9_col8, #T_914ca_row9_col11, #T_914ca_row11_col9 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_914ca_row0_col14, #T_914ca_row1_col14, #T_914ca_row3_col14, #T_914ca_row6_col14 {
#   background-color: #a20643;
#   color: #f1f1f1;
# }
# #T_914ca_row1_col2, #T_914ca_row2_col1 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_914ca_row1_col5, #T_914ca_row5_col0, #T_914ca_row5_col6, #T_914ca_row11_col5 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_914ca_row1_col9, #T_914ca_row6_col9, #T_914ca_row8_col9, #T_914ca_row9_col1, #T_914ca_row9_col7, #T_914ca_row9_col12, #T_914ca_row9_col13 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_914ca_row1_col10, #T_914ca_row3_col7, #T_914ca_row3_col12, #T_914ca_row3_col13, #T_914ca_row4_col7, #T_914ca_row4_col12, #T_914ca_row4_col13, #T_914ca_row6_col7, #T_914ca_row6_col8, #T_914ca_row6_col10, #T_914ca_row6_col13, #T_914ca_row7_col3, #T_914ca_row7_col4, #T_914ca_row7_col6, #T_914ca_row7_col10, #T_914ca_row8_col6, #T_914ca_row8_col10, #T_914ca_row10_col1, #T_914ca_row10_col6, #T_914ca_row10_col7, #T_914ca_row10_col8, #T_914ca_row10_col12, #T_914ca_row10_col13, #T_914ca_row12_col3, #T_914ca_row12_col4, #T_914ca_row12_col10, #T_914ca_row13_col3, #T_914ca_row13_col4, #T_914ca_row13_col6, #T_914ca_row13_col10 {
#   background-color: #5c51a3;
#   color: #f1f1f1;
# }
# #T_914ca_row2_col3, #T_914ca_row2_col4, #T_914ca_row3_col2, #T_914ca_row4_col2 {
#   background-color: #5b53a4;
#   color: #f1f1f1;
# }
# #T_914ca_row2_col5 {
#   background-color: #c1e6a0;
#   color: #000000;
# }
# #T_914ca_row2_col7, #T_914ca_row2_col8, #T_914ca_row2_col12, #T_914ca_row2_col13, #T_914ca_row3_col9, #T_914ca_row7_col2, #T_914ca_row8_col2, #T_914ca_row9_col0, #T_914ca_row9_col3, #T_914ca_row12_col2, #T_914ca_row13_col2 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_914ca_row2_col9, #T_914ca_row2_col11, #T_914ca_row4_col9, #T_914ca_row9_col2, #T_914ca_row9_col4, #T_914ca_row11_col2 {
#   background-color: #555aa7;
#   color: #f1f1f1;
# }
# #T_914ca_row2_col14 {
#   background-color: #b81e48;
#   color: #f1f1f1;
# }
# #T_914ca_row3_col5 {
#   background-color: #8cd1a4;
#   color: #000000;
# }
# #T_914ca_row4_col5 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_914ca_row4_col14 {
#   background-color: #a70b44;
#   color: #f1f1f1;
# }
# #T_914ca_row5_col1, #T_914ca_row5_col11 {
#   background-color: #64c0a6;
#   color: #000000;
# }
# #T_914ca_row5_col2 {
#   background-color: #b8e2a1;
#   color: #000000;
# }
# #T_914ca_row5_col4 {
#   background-color: #81cda5;
#   color: #000000;
# }
# #T_914ca_row5_col7, #T_914ca_row5_col13 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_914ca_row5_col8 {
#   background-color: #62bda7;
#   color: #000000;
# }
# #T_914ca_row5_col9, #T_914ca_row9_col5 {
#   background-color: #cfec9d;
#   color: #000000;
# }
# #T_914ca_row5_col10 {
#   background-color: #86cfa5;
#   color: #000000;
# }
# #T_914ca_row5_col12 {
#   background-color: #5eb9a9;
#   color: #f1f1f1;
# }
# #T_914ca_row5_col14 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_914ca_row7_col5, #T_914ca_row13_col5 {
#   background-color: #6bc4a5;
#   color: #000000;
# }
# #T_914ca_row7_col9, #T_914ca_row12_col9, #T_914ca_row13_col9 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_914ca_row7_col14, #T_914ca_row8_col14, #T_914ca_row13_col14, #T_914ca_row14_col0, #T_914ca_row14_col1, #T_914ca_row14_col2, #T_914ca_row14_col3, #T_914ca_row14_col4, #T_914ca_row14_col5, #T_914ca_row14_col6, #T_914ca_row14_col7, #T_914ca_row14_col8, #T_914ca_row14_col9, #T_914ca_row14_col10, #T_914ca_row14_col11, #T_914ca_row14_col12, #T_914ca_row14_col13 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_914ca_row8_col5 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_914ca_row9_col14 {
#   background-color: #d0384e;
#   color: #f1f1f1;
# }
# #T_914ca_row10_col5 {
#   background-color: #91d3a4;
#   color: #000000;
# }
# #T_914ca_row10_col14 {
#   background-color: #af1446;
#   color: #f1f1f1;
# }
# #T_914ca_row11_col14, #T_914ca_row12_col14 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_914ca_row12_col5 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# </style>
# <table id="T_914ca_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >10</th>
#       <th class="col_heading level0 col10" >11</th>
#       <th class="col_heading level0 col11" >12</th>
#       <th class="col_heading level0 col12" >13</th>
#       <th class="col_heading level0 col13" >14</th>
#       <th class="col_heading level0 col14" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_914ca_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_914ca_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_914ca_row0_col1" class="data row0 col1" >0.997702</td>
#       <td id="T_914ca_row0_col2" class="data row0 col2" >0.972535</td>
#       <td id="T_914ca_row0_col3" class="data row0 col3" >0.998382</td>
#       <td id="T_914ca_row0_col4" class="data row0 col4" >0.998616</td>
#       <td id="T_914ca_row0_col5" class="data row0 col5" >0.602925</td>
#       <td id="T_914ca_row0_col6" class="data row0 col6" >0.997309</td>
#       <td id="T_914ca_row0_col7" class="data row0 col7" >0.997297</td>
#       <td id="

# %% [markdown]
# Ripser features & accuracy validation set

# %%
corr = eval_mean_res.corr()
corr.style.background_gradient(cmap='Spectral')
# Out:
# <style type="text/css">
# #T_f61dd_row0_col0, #T_f61dd_row0_col1, #T_f61dd_row0_col3, #T_f61dd_row0_col4, #T_f61dd_row0_col7, #T_f61dd_row0_col8, #T_f61dd_row0_col11, #T_f61dd_row0_col12, #T_f61dd_row0_col13, #T_f61dd_row1_col0, #T_f61dd_row1_col1, #T_f61dd_row1_col3, #T_f61dd_row1_col4, #T_f61dd_row1_col8, #T_f61dd_row1_col11, #T_f61dd_row1_col12, #T_f61dd_row2_col2, #T_f61dd_row3_col0, #T_f61dd_row3_col1, #T_f61dd_row3_col3, #T_f61dd_row3_col4, #T_f61dd_row3_col7, #T_f61dd_row3_col8, #T_f61dd_row3_col11, #T_f61dd_row3_col12, #T_f61dd_row3_col13, #T_f61dd_row4_col0, #T_f61dd_row4_col1, #T_f61dd_row4_col3, #T_f61dd_row4_col4, #T_f61dd_row4_col7, #T_f61dd_row4_col8, #T_f61dd_row4_col11, #T_f61dd_row4_col12, #T_f61dd_row4_col13, #T_f61dd_row5_col5, #T_f61dd_row6_col6, #T_f61dd_row7_col0, #T_f61dd_row7_col3, #T_f61dd_row7_col4, #T_f61dd_row7_col7, #T_f61dd_row7_col8, #T_f61dd_row7_col11, #T_f61dd_row7_col12, #T_f61dd_row7_col13, #T_f61dd_row8_col0, #T_f61dd_row8_col3, #T_f61dd_row8_col4, #T_f61dd_row8_col7, #T_f61dd_row8_col8, #T_f61dd_row8_col11, #T_f61dd_row8_col12, #T_f61dd_row8_col13, #T_f61dd_row9_col9, #T_f61dd_row10_col10, #T_f61dd_row11_col0, #T_f61dd_row11_col1, #T_f61dd_row11_col3, #T_f61dd_row11_col4, #T_f61dd_row11_col7, #T_f61dd_row11_col8, #T_f61dd_row11_col11, #T_f61dd_row11_col12, #T_f61dd_row11_col13, #T_f61dd_row12_col0, #T_f61dd_row12_col1, #T_f61dd_row12_col3, #T_f61dd_row12_col4, #T_f61dd_row12_col7, #T_f61dd_row12_col8, #T_f61dd_row12_col11, #T_f61dd_row12_col12, #T_f61dd_row12_col13, #T_f61dd_row13_col0, #T_f61dd_row13_col3, #T_f61dd_row13_col4, #T_f61dd_row13_col7, #T_f61dd_row13_col8, #T_f61dd_row13_col11, #T_f61dd_row13_col12, #T_f61dd_row13_col13, #T_f61dd_row14_col14 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_f61dd_row0_col2, #T_f61dd_row0_col6, #T_f61dd_row0_col10, #T_f61dd_row1_col6, #T_f61dd_row1_col10, #T_f61dd_row2_col0, #T_f61dd_row2_col8, #T_f61dd_row2_col10, #T_f61dd_row2_col12, #T_f61dd_row6_col0, #T_f61dd_row6_col8, #T_f61dd_row6_col12, #T_f61dd_row8_col6, #T_f61dd_row10_col0, #T_f61dd_row10_col7, #T_f61dd_row10_col8, #T_f61dd_row10_col12, #T_f61dd_row10_col13, #T_f61dd_row12_col2, #T_f61dd_row12_col6, #T_f61dd_row12_col10 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_f61dd_row0_col5, #T_f61dd_row8_col5, #T_f61dd_row8_col9 {
#   background-color: #4ba4b1;
#   color: #f1f1f1;
# }
# #T_f61dd_row0_col9, #T_f61dd_row12_col9 {
#   background-color: #459eb4;
#   color: #f1f1f1;
# }
# #T_f61dd_row0_col14, #T_f61dd_row12_col14 {
#   background-color: #de4c4b;
#   color: #f1f1f1;
# }
# #T_f61dd_row1_col2, #T_f61dd_row2_col1, #T_f61dd_row2_col4, #T_f61dd_row2_col11, #T_f61dd_row3_col6, #T_f61dd_row4_col2, #T_f61dd_row4_col10, #T_f61dd_row6_col3, #T_f61dd_row6_col7, #T_f61dd_row6_col13, #T_f61dd_row7_col6, #T_f61dd_row10_col1, #T_f61dd_row10_col2, #T_f61dd_row10_col4, #T_f61dd_row10_col11, #T_f61dd_row11_col2, #T_f61dd_row11_col10, #T_f61dd_row13_col6 {
#   background-color: #5b53a4;
#   color: #f1f1f1;
# }
# #T_f61dd_row1_col5, #T_f61dd_row5_col3, #T_f61dd_row7_col9, #T_f61dd_row9_col6, #T_f61dd_row12_col5, #T_f61dd_row13_col9 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_f61dd_row1_col7, #T_f61dd_row1_col13, #T_f61dd_row7_col1, #T_f61dd_row8_col1, #T_f61dd_row13_col1 {
#   background-color: #5c51a3;
#   color: #f1f1f1;
# }
# #T_f61dd_row1_col9 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# #T_f61dd_row1_col14, #T_f61dd_row4_col14, #T_f61dd_row11_col14 {
#   background-color: #e2514a;
#   color: #f1f1f1;
# }
# #T_f61dd_row2_col3, #T_f61dd_row2_col7, #T_f61dd_row2_col13, #T_f61dd_row3_col2, #T_f61dd_row4_col6, #T_f61dd_row6_col1, #T_f61dd_row6_col4, #T_f61dd_row6_col11, #T_f61dd_row7_col2, #T_f61dd_row7_col10, #T_f61dd_row8_col2, #T_f61dd_row8_col10, #T_f61dd_row10_col3, #T_f61dd_row11_col6, #T_f61dd_row13_col2, #T_f61dd_row13_col10 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_f61dd_row2_col5 {
#   background-color: #76c8a5;
#   color: #000000;
# }
# #T_f61dd_row2_col6 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_f61dd_row2_col9, #T_f61dd_row9_col1 {
#   background-color: #3682ba;
#   color: #f1f1f1;
# }
# #T_f61dd_row2_col14 {
#   background-color: #f26944;
#   color: #f1f1f1;
# }
# #T_f61dd_row3_col5 {
#   background-color: #439bb5;
#   color: #f1f1f1;
# }
# #T_f61dd_row3_col9, #T_f61dd_row5_col7, #T_f61dd_row5_col13, #T_f61dd_row11_col5 {
#   background-color: #54aead;
#   color: #f1f1f1;
# }
# #T_f61dd_row3_col10 {
#   background-color: #555aa7;
#   color: #f1f1f1;
# }
# #T_f61dd_row3_col14 {
#   background-color: #d8434e;
#   color: #f1f1f1;
# }
# #T_f61dd_row4_col5 {
#   background-color: #52abae;
#   color: #f1f1f1;
# }
# #T_f61dd_row4_col9, #T_f61dd_row11_col9 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
# }
# #T_f61dd_row5_col0 {
#   background-color: #58b2ac;
#   color: #f1f1f1;
# }
# #T_f61dd_row5_col1 {
#   background-color: #5cb7aa;
#   color: #f1f1f1;
# }
# #T_f61dd_row5_col2, #T_f61dd_row5_col10 {
#   background-color: #99d6a4;
#   color: #000000;
# }
# #T_f61dd_row5_col4 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_f61dd_row5_col6, #T_f61dd_row9_col3 {
#   background-color: #3990ba;
#   color: #f1f1f1;
# }
# #T_f61dd_row5_col8 {
#   background-color: #56b0ad;
#   color: #f1f1f1;
# }
# #T_f61dd_row5_col9 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_f61dd_row5_col11 {
#   background-color: #62bda7;
#   color: #000000;
# }
# #T_f61dd_row5_col12 {
#   background-color: #5ab4ab;
#   color: #f1f1f1;
# }
# #T_f61dd_row5_col14, #T_f61dd_row14_col0, #T_f61dd_row14_col1, #T_f61dd_row14_col2, #T_f61dd_row14_col3, #T_f61dd_row14_col4, #T_f61dd_row14_col5, #T_f61dd_row14_col6, #T_f61dd_row14_col7, #T_f61dd_row14_col8, #T_f61dd_row14_col9, #T_f61dd_row14_col10, #T_f61dd_row14_col11, #T_f61dd_row14_col12, #T_f61dd_row14_col13 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_f61dd_row6_col2 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_f61dd_row6_col5, #T_f61dd_row9_col7, #T_f61dd_row9_col13 {
#   background-color: #358bbc;
#   color: #f1f1f1;
# }
# #T_f61dd_row6_col9 {
#   background-color: #81cda5;
#   color: #000000;
# }
# #T_f61dd_row6_col10 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_f61dd_row6_col14 {
#   background-color: #c32a4b;
#   color: #f1f1f1;
# }
# #T_f61dd_row7_col5, #T_f61dd_row13_col5 {
#   background-color: #49a2b2;
#   color: #f1f1f1;
# }
# #T_f61dd_row7_col14, #T_f61dd_row13_col14 {
#   background-color: #da464d;
#   color: #f1f1f1;
# }
# #T_f61dd_row8_col14 {
#   background-color: #dc484c;
#   color: #f1f1f1;
# }
# #T_f61dd_row9_col0 {
#   background-color: #3387bc;
#   color: #f1f1f1;
# }
# #T_f61dd_row9_col2 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_f61dd_row9_col4, #T_f61dd_row9_col11 {
#   background-color: #3880b9;
#   color: #f1f1f1;
# }
# #T_f61dd_row9_col5 {
#   background-color: #dff299;
#   color: #000000;
# }
# #T_f61dd_row9_col8 {
#   background-color: #3389bd;
#   color: #f1f1f1;
# }
# #T_f61dd_row9_col10 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_f61dd_row9_col12 {
#   background-color: #3585bb;
#   color: #f1f1f1;
# }
# #T_f61dd_row9_col14 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_f61dd_row10_col5 {
#   background-color: #71c6a5;
#   color: #000000;
# }
# #T_f61dd_row10_col6 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_f61dd_row10_col9 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_f61dd_row10_col14 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f61dd_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >10</th>
#       <th class="col_heading level0 col10" >11</th>
#       <th class="col_heading level0 col11" >12</th>
#       <th class="col_heading level0 col12" >13</th>
#       <

# %% [markdown]
# Graph features & accuracy train set

# %%
graph_feature_names=[
    's', # 1 - number of strongly connected components
    'w', # 2 - number of weakly connected components
    'e', # 3 - number of edges
    'v', # 4 - average vertex degree
    'c', # 5 - number of (directed) simple cycles
    'b0', # 6 - Betti numbers
    'b1', # 7 - Betti numbers
    'm', # 8 - ..
    'k' # 9 - ..
]

# %%
corr = train_mean_res.corr()
corr.style.background_gradient(cmap='Spectral')
# Out:
# <style type="text/css">
# #T_d81e8_row0_col0, #T_d81e8_row0_col2, #T_d81e8_row0_col6, #T_d81e8_row0_col7, #T_d81e8_row1_col1, #T_d81e8_row1_col2, #T_d81e8_row1_col5, #T_d81e8_row1_col6, #T_d81e8_row1_col7, #T_d81e8_row2_col0, #T_d81e8_row2_col1, #T_d81e8_row2_col2, #T_d81e8_row2_col5, #T_d81e8_row2_col6, #T_d81e8_row2_col7, #T_d81e8_row3_col3, #T_d81e8_row3_col4, #T_d81e8_row4_col3, #T_d81e8_row4_col4, #T_d81e8_row5_col1, #T_d81e8_row5_col2, #T_d81e8_row5_col5, #T_d81e8_row5_col6, #T_d81e8_row5_col7, #T_d81e8_row6_col0, #T_d81e8_row6_col1, #T_d81e8_row6_col2, #T_d81e8_row6_col5, #T_d81e8_row6_col6, #T_d81e8_row6_col7, #T_d81e8_row7_col0, #T_d81e8_row7_col1, #T_d81e8_row7_col2, #T_d81e8_row7_col5, #T_d81e8_row7_col6, #T_d81e8_row7_col7, #T_d81e8_row8_col8, #T_d81e8_row9_col9 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_d81e8_row0_col1, #T_d81e8_row0_col5, #T_d81e8_row1_col0, #T_d81e8_row5_col0 {
#   background-color: #5c51a3;
#   color: #f1f1f1;
# }
# #T_d81e8_row0_col3 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_d81e8_row0_col4, #T_d81e8_row9_col8 {
#   background-color: #3d79b6;
#   color: #f1f1f1;
# }
# #T_d81e8_row0_col8, #T_d81e8_row0_col9, #T_d81e8_row2_col8, #T_d81e8_row6_col8, #T_d81e8_row7_col8, #T_d81e8_row7_col9, #T_d81e8_row8_col0, #T_d81e8_row8_col1, #T_d81e8_row8_col2, #T_d81e8_row8_col3, #T_d81e8_row8_col4, #T_d81e8_row8_col5, #T_d81e8_row8_col6, #T_d81e8_row8_col7 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_d81e8_row1_col3, #T_d81e8_row5_col3 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_d81e8_row1_col4, #T_d81e8_row2_col3, #T_d81e8_row3_col2, #T_d81e8_row5_col4 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_d81e8_row1_col8, #T_d81e8_row2_col9, #T_d81e8_row5_col8 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_d81e8_row1_col9, #T_d81e8_row5_col9 {
#   background-color: #a40844;
#   color: #f1f1f1;
# }
# #T_d81e8_row2_col4, #T_d81e8_row3_col7, #T_d81e8_row4_col2, #T_d81e8_row7_col3 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_d81e8_row3_col0, #T_d81e8_row7_col4 {
#   background-color: #4471b2;
#   color: #f1f1f1;
# }
# #T_d81e8_row3_col1, #T_d81e8_row3_col5 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_d81e8_row3_col6, #T_d81e8_row4_col1, #T_d81e8_row4_col5, #T_d81e8_row6_col3 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_d81e8_row3_col8 {
#   background-color: #bc2249;
#   color: #f1f1f1;
# }
# #T_d81e8_row3_col9 {
#   background-color: #cb334d;
#   color: #f1f1f1;
# }
# #T_d81e8_row4_col0 {
#   background-color: #3f77b5;
#   color: #f1f1f1;
# }
# #T_d81e8_row4_col6, #T_d81e8_row6_col4 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_d81e8_row4_col7 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_d81e8_row4_col8, #T_d81e8_row9_col0 {
#   background-color: #c32a4b;
#   color: #f1f1f1;
# }
# #T_d81e8_row4_col9, #T_d81e8_row9_col4 {
#   background-color: #d23a4e;
#   color: #f1f1f1;
# }
# #T_d81e8_row6_col9 {
#   background-color: #a20643;
#   color: #f1f1f1;
# }
# #T_d81e8_row8_col9 {
#   background-color: #3b7cb7;
#   color: #f1f1f1;
# }
# #T_d81e8_row9_col1, #T_d81e8_row9_col5 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
# }
# #T_d81e8_row9_col2, #T_d81e8_row9_col6, #T_d81e8_row9_col7 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
# }
# #T_d81e8_row9_col3 {
#   background-color: #d43d4f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d81e8_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d81e8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d81e8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d81e8_row0_col1" class="data row0 col1" >0.987622</td>
#       <td id="T_d81e8_row0_col2" class="data row0 col2" >0.994843</td>
#       <td id="T_d81e8_row0_col3" class="data row0 col3" >0.878409</td>
#       <td id="T_d81e8_row0_col4" class="data row0 col4" >0.858486</td>
#       <td id="T_d81e8_row0_col5" class="data row0 col5" >0.987622</td>
#       <td id="T_d81e8_row0_col6" class="data row0 col6" >0.992317</td>
#       <td id="T_d81e8_row0_col7" class="data row0 col7" >0.998020</td>
#       <td id="T_d81e8_row0_col8" class="data row0 col8" >-0.996680</td>
#       <td id="T_d81e8_row0_col9" class="data row0 col9" >-0.857198</td>
#     </tr>
#     <tr>
#       <th id="T_d81e8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d81e8_row1_col0" class="data row1 col0" >0.987622</td>
#       <td id="T_d81e8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d81e8_row1_col2" class="data row1 col2" >0.998305</td>
#       <td id="T_d81e8_row1_col3" class="data row1 col3" >0.940533</td>
#       <td id="T_d81e8_row1_col4" class="data row1 col4" >0.926472</td>
#       <td id="T_d81e8_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_d81e8_row1_col6" class="data row1 col6" >0.999399</td>
#       <td id="T_d81e8_row1_col7" class="data row1 col7" >0.994703</td>
#       <td id="T_d81e8_row1_col8" class="data row1 col8" >-0.984476</td>
#       <td id="T_d81e8_row1_col9" class="data row1 col9" >-0.833340</td>
#     </tr>
#     <tr>
#       <th id="T_d81e8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d81e8_row2_col0" class="data row2 col0" >0.994843</td>
#       <td id="T_d81e8_row2_col1" class="data row2 col1" >0.998305</td>
#       <td id="T_d81e8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d81e8_row2_col3" class="data row2 col3" >0.921855</td>
#       <td id="T_d81e8_row2_col4" class="data row2 col4" >0.905588</td>
#       <td id="T_d81e8_row2_col5" class="data row2 col5" >0.998305</td>
#       <td id="T_d81e8_row2_col6" class="data row2 col6" >0.999700</td>
#       <td id="T_d81e8_row2_col7" class="data row2 col7" >0.998951</td>
#       <td id="T_d81e8_row2_col8" class="data row2 col8" >-0.992572</td>
#       <td id="T_d81e8_row2_col9" class="data row2 col9" >-0.845016</td>
#     </tr>
#     <tr>
#       <th id="T_d81e8_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d81e8_row3_col0" class="data row3 col0" >0.878409</td>
#       <td id="T_d81e8_row3_col1" class="data row3 col1" >0.940533</td>
#       <td id="T_d81e8_row3_col2" class="data row3 col2" >0.921855</td>
#       <td id="T_d81e8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d81e8_row3_col4" class="data row3 col4" >0.998598</td>
#       <td id="T_d81e8_row3_col5" class="data row3 col5" >0.940533</td>
#       <td id="T_d81e8_row3_col6" class="data row3 col6" >0.929537</td>
#       <td id="T_d81e8_row3_col7" class="data row3 col7" >0.905292</td>
#       <td id="T_d81e8_row3_col8" class="data row3 col8" >-0.883746</td>
#       <td id="T_d81e8_row3_col9" class="data row3 col9" >-0.699595</td>
#     </tr>
#     <tr>
#       <th id="T_d81e8_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d81e8_row4_col0" class="data row4 col0" >0.858486</td>
#       <td id="T_d81e8_row4_col1" class="data row4 col1" >0.926472</td>
#       <td id="T_d81e8_row4_col2" class="data row4 col2" >0.905588</td>
#       <td id="T_d81e8_row4_col3" class="data row4 col3" >0.998598</td>
#       <td id="T_d81e8_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_d81e8_row4_col5" class="data row4 col5" >0.926472</td>
#       <td id="T_d81e8_row4_col6" class="data row4 col6" >0.914131</td>
#       <td id="T_d81e8_row4_col7" class="data row4 col7" >0.887533</td>
#       <td id="T_d81e8_row4_col8" class="data row4 col8" >-0.863359</td>
#       <td id="T_d81e8_row4_col9" class="data row4 col9" >-0.682184</td>
#     </tr>
#     <tr>
#       <th id="T_d81e8_level0_row5" cl

# %% [markdown]
# Graph features & accuracy validation set

# %%
corr = eval_mean_res.corr()
corr.style.background_gradient(cmap='Spectral')
# Out:
# <style type="text/css">
# #T_629ab_row0_col0, #T_629ab_row0_col1, #T_629ab_row0_col2, #T_629ab_row0_col5, #T_629ab_row0_col6, #T_629ab_row0_col7, #T_629ab_row1_col0, #T_629ab_row1_col1, #T_629ab_row1_col2, #T_629ab_row1_col5, #T_629ab_row1_col6, #T_629ab_row1_col7, #T_629ab_row2_col0, #T_629ab_row2_col1, #T_629ab_row2_col2, #T_629ab_row2_col5, #T_629ab_row2_col6, #T_629ab_row2_col7, #T_629ab_row3_col3, #T_629ab_row4_col4, #T_629ab_row5_col0, #T_629ab_row5_col1, #T_629ab_row5_col2, #T_629ab_row5_col5, #T_629ab_row5_col6, #T_629ab_row5_col7, #T_629ab_row6_col0, #T_629ab_row6_col1, #T_629ab_row6_col2, #T_629ab_row6_col5, #T_629ab_row6_col6, #T_629ab_row6_col7, #T_629ab_row7_col0, #T_629ab_row7_col1, #T_629ab_row7_col2, #T_629ab_row7_col5, #T_629ab_row7_col6, #T_629ab_row7_col7, #T_629ab_row8_col8, #T_629ab_row9_col9 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_629ab_row0_col3, #T_629ab_row3_col7, #T_629ab_row4_col1, #T_629ab_row4_col5 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_629ab_row0_col4, #T_629ab_row7_col4 {
#   background-color: #3d79b6;
#   color: #f1f1f1;
# }
# #T_629ab_row0_col8, #T_629ab_row2_col8, #T_629ab_row7_col8, #T_629ab_row7_col9, #T_629ab_row8_col0, #T_629ab_row8_col1, #T_629ab_row8_col2, #T_629ab_row8_col3, #T_629ab_row8_col4, #T_629ab_row8_col5, #T_629ab_row8_col6, #T_629ab_row8_col7 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_629ab_row0_col9 {
#   background-color: #a20643;
#   color: #f1f1f1;
# }
# #T_629ab_row1_col3, #T_629ab_row3_col6, #T_629ab_row5_col3 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_629ab_row1_col4, #T_629ab_row4_col6, #T_629ab_row5_col4, #T_629ab_row7_col3 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_629ab_row1_col8, #T_629ab_row5_col8, #T_629ab_row6_col8 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_629ab_row1_col9, #T_629ab_row5_col9 {
#   background-color: #b11747;
#   color: #f1f1f1;
# }
# #T_629ab_row2_col3 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_629ab_row2_col4 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_629ab_row2_col9 {
#   background-color: #a90d45;
#   color: #f1f1f1;
# }
# #T_629ab_row3_col0 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
# }
# #T_629ab_row3_col1, #T_629ab_row3_col5 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_629ab_row3_col2, #T_629ab_row6_col3 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_629ab_row3_col4, #T_629ab_row4_col3 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_629ab_row3_col8 {
#   background-color: #c32a4b;
#   color: #f1f1f1;
# }
# #T_629ab_row3_col9 {
#   background-color: #ef6645;
#   color: #f1f1f1;
# }
# #T_629ab_row4_col0, #T_629ab_row4_col7 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_629ab_row4_col2 {
#   background-color: #466eb1;
#   color: #f1f1f1;
# }
# #T_629ab_row4_col8 {
#   background-color: #cd364d;
#   color: #f1f1f1;
# }
# #T_629ab_row4_col9 {
#   background-color: #ee6445;
#   color: #f1f1f1;
# }
# #T_629ab_row6_col4 {
#   background-color: #4471b2;
#   color: #f1f1f1;
# }
# #T_629ab_row6_col9 {
#   background-color: #ab0f45;
#   color: #f1f1f1;
# }
# #T_629ab_row8_col9 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# #T_629ab_row9_col0 {
#   background-color: #e3534a;
#   color: #f1f1f1;
# }
# #T_629ab_row9_col1, #T_629ab_row9_col5 {
#   background-color: #e95c47;
#   color: #f1f1f1;
# }
# #T_629ab_row9_col2 {
#   background-color: #e55749;
#   color: #f1f1f1;
# }
# #T_629ab_row9_col3 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_629ab_row9_col4 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_629ab_row9_col6 {
#   background-color: #e75948;
#   color: #f1f1f1;
# }
# #T_629ab_row9_col7 {
#   background-color: #e1504b;
#   color: #f1f1f1;
# }
# #T_629ab_row9_col8 {
#   background-color: #378ebb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_629ab_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_629ab_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_629ab_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_629ab_row0_col1" class="data row0 col1" >0.995558</td>
#       <td id="T_629ab_row0_col2" class="data row0 col2" >0.998515</td>
#       <td id="T_629ab_row0_col3" class="data row0 col3" >0.907359</td>
#       <td id="T_629ab_row0_col4" class="data row0 col4" >0.861213</td>
#       <td id="T_629ab_row0_col5" class="data row0 col5" >0.995558</td>
#       <td id="T_629ab_row0_col6" class="data row0 col6" >0.997482</td>
#       <td id="T_629ab_row0_col7" class="data row0 col7" >0.999017</td>
#       <td id="T_629ab_row0_col8" class="data row0 col8" >-0.991586</td>
#       <td id="T_629ab_row0_col9" class="data row0 col9" >-0.699855</td>
#     </tr>
#     <tr>
#       <th id="T_629ab_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_629ab_row1_col0" class="data row1 col0" >0.995558</td>
#       <td id="T_629ab_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_629ab_row1_col2" class="data row1 col2" >0.999027</td>
#       <td id="T_629ab_row1_col3" class="data row1 col3" >0.941077</td>
#       <td id="T_629ab_row1_col4" class="data row1 col4" >0.902598</td>
#       <td id="T_629ab_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_629ab_row1_col6" class="data row1 col6" >0.999607</td>
#       <td id="T_629ab_row1_col7" class="data row1 col7" >0.994984</td>
#       <td id="T_629ab_row1_col8" class="data row1 col8" >-0.979437</td>
#       <td id="T_629ab_row1_col9" class="data row1 col9" >-0.654169</td>
#     </tr>
#     <tr>
#       <th id="T_629ab_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_629ab_row2_col0" class="data row2 col0" >0.998515</td>
#       <td id="T_629ab_row2_col1" class="data row2 col1" >0.999027</td>
#       <td id="T_629ab_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_629ab_row2_col3" class="data row2 col3" >0.926624</td>
#       <td id="T_629ab_row2_col4" class="data row2 col4" >0.886132</td>
#       <td id="T_629ab_row2_col5" class="data row2 col5" >0.999027</td>
#       <td id="T_629ab_row2_col6" class="data row2 col6" >0.999827</td>
#       <td id="T_629ab_row2_col7" class="data row2 col7" >0.998256</td>
#       <td id="T_629ab_row2_col8" class="data row2 col8" >-0.986899</td>
#       <td id="T_629ab_row2_col9" class="data row2 col9" >-0.680326</td>
#     </tr>
#     <tr>
#       <th id="T_629ab_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_629ab_row3_col0" class="data row3 col0" >0.907359</td>
#       <td id="T_629ab_row3_col1" class="data row3 col1" >0.941077</td>
#       <td id="T_629ab_row3_col2" class="data row3 col2" >0.926624</td>
#       <td id="T_629ab_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_629ab_row3_col4" class="data row3 col4" >0.977386</td>
#       <td id="T_629ab_row3_col5" class="data row3 col5" >0.941077</td>
#       <td id="T_629ab_row3_col6" class="data row3 col6" >0.932293</td>
#       <td id="T_629ab_row3_col7" class="data row3 col7" >0.905281</td>
#       <td id="T_629ab_row3_col8" class="data row3 col8" >-0.860709</td>
#       <td id="T_629ab_row3_col9" class="data row3 col9" >-0.401700</td>
#     </tr>
#     <tr>
#       <th id="T_629ab_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_629ab_row4_col0" class="data row4 col0" >0.861213</td>
#       <td id="T_629ab_row4_col1" class="data row4 col1" >0.902598</td>
#       <td id="T_629ab_row4_col2" class="data row4 col2" >0.886132</td>
#       <td id="T_629ab_row4_col3" class="data row4 col3" >0.977386</td>
#       <td id="T_629ab_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id=
